# %%
#Export dependencies
import pandas as pd

# %%
#Export data for cleaning
data = "Resources\Chicago_Energy_Benchmarking.csv"
chicago_energy_data = pd.read_csv(data)


chicago_energy_data.head()
# Out:
#    Data Year      ID              Property Name Reporting Status  \
# 0       2020  252064           Mansueto Library   Submitted Data
# 1       2020  232458  Harper Square Cooperative   Submitted Data
# 2       2020  254616       Former Coyne College   Submitted Data
# 3       2020  103812          400 W Superior St   Submitted Data
# 4       2020  254073            Blue Moon Lofts   Submitted Data
#
#                        Address ZIP Code  Chicago Energy Rating  \
# 0               1100 E 57th St    60637                    2.0
# 1  4800 - 4850 S Lake Park Ave    60615                    1.0
# 2               330 N Green St    60607                    2.0
# 3            400 W Superior St    60654                    3.0
# 4          215 N. Aberdeen St.    60607                    4.0
#
#   Exempt From Chicago Energy Rating   Community Area Primary Property Type  \
# 0                             False        HYDE PARK               Library
# 1                             False          KENWOOD   Multifamily Housing
# 2                             False   NEAR WEST SIDE                Office
# 3                             False  NEAR NORTH SIDE                Office
# 4                             False   NEAR WEST SIDE   Multifamily Housing
#
#    ...  Site EUI (kBtu/sq ft)  Source EUI (kBtu/sq ft)  \
# 0  ...                  240.8                    323.6
# 1  ...                   95.5                    146.0
# 2  ...                   55.5                    148.3
# 3  ...                   61.4                    151.8
# 4  ...                   29.4                     64.9
#
#    Weather Normalized Site EUI (kBtu/sq ft)  \
# 0                                     246.0
# 1                                     100.3
# 2                                      56.7
# 3                                      63.0
# 4                                      29.6
#
#    Weather Normalized Source EUI (kBtu/sq ft)  \
# 0                                       329.9
# 1                                       150.7
# 2                                       151.8
# 3                                       154.8
# 4                                        64.3
#
#    Total GHG Emissions (Metric Tons CO2e)  GHG Intensity (kg CO2e/sq ft)  \
# 0                                  1160.9                           18.1
# 1                                  4871.7                            7.8
# 2                                  4581.4                            8.2
# 3                                  1092.1                            8.4
# 4                                   295.8                            3.6
#
#     Latitude  Longitude                     Location       Row_ID
# 0  41.792213 -87.599950  (41.79221307, -87.59994981)  2020-252064
# 1  41.807475 -87.591264  (41.80747487, -87.59126397)  2020-232458
# 2  41.873335 -87.651021    (41.873335, -87.65102071)  2020-254616
# 3  41.895752 -87.638901    (41.89575232, -87.638901)  2020-103812
# 4  41.874295 -87.650175  (41.87429514, -87.65017516)  2020-254073
#
# [5 rows x 30 columns]

# %% [markdown]
# # View imported data

# %%
chicago_energy_data = chicago_energy_data.set_index('ID')

# %%
#Check dimensions of data 
print(f'Number of columns: {chicago_energy_data.columns.nunique()}')
print(f'Number of rows: {len(chicago_energy_data)}')
# Out:
# Number of columns: 29
# Number of rows: 17728

# %%
#Extracting exempt buildings
exempt_chicago_energy = chicago_energy_data.loc[(chicago_energy_data["Reporting Status"]) == 'Exempt']
print(len(exempt_chicago_energy))
# Out:
# 474

# %%
nonexempt_chicago_energy = chicago_energy_data.loc[(chicago_energy_data["Reporting Status"]) != 'Exempt']
print(len(nonexempt_chicago_energy))
# Out:
# 17254

# %%
#Dropping unnecessary columns
nonexempt_chicago_energy = nonexempt_chicago_energy.drop(columns='Row_ID')

# %% [markdown]
# # Check for null values

# %%
#Each row has an Chicago Energy Rating
null_val_energy_rating = (nonexempt_chicago_energy["Chicago Energy Rating"]).notnull()
null_val_energy_rating.describe
# Out:
# <bound method NDFrame.describe of         Data Year  Property Name  Reporting Status  Address  ZIP Code  \
# ID
# 252064       True           True              True     True      True
# 232458       True           True              True     True      True
# 254616       True           True              True     True      True
# 103812       True           True              True     True      True
# 254073       True           True              True     True      True
# ...           ...            ...               ...      ...       ...
# 260132       True           True              True     True      True
# 260135       True           True              True     True      True
# 260149       True           True              True     True      True
# 260150       True           True              True     True      True
# 260184       True           True              True     True      True
#
#         Chicago Energy Rating  Exempt From Chicago Energy Rating  \
# ID
# 252064                   True                               True
# 232458                   True                               True
# 254616                   True                               True
# 103812                   True                               True
# 254073                   True                               True
# ...                       ...                                ...
# 260132                   True                               True
# 260135                   True                               True
# 260149                   True                               True
# 260150                   True                               True
# 260184                   True                               True
#
#         Community Area  Primary Property Type  \
# ID
# 252064            True                   True
# 232458            True                   True
# 254616            True                   True
# 103812            True                   True
# 254073            True                   True
# ...                ...                    ...
# 260132            True                  False
# 260135            True                   True
# 260149            True                   True
# 260150            True                   True
# 260184            True                   True
#
#         Gross Floor Area - Buildings (sq ft)  ...  All Other Fuel Use (kBtu)  \
# ID                                            ...
# 252064                                  True  ...                      False
# 232458                                  True  ...                      False
# 254616                                  True  ...                      False
# 103812                                  True  ...                      False
# 254073                                  True  ...                      False
# ...                                      ...  ...                        ...
# 260132                                 False  ...                      False
# 260135                                  True  ...                      False
# 260149                                  True  ...                      False
# 260150                                  True  ...                      False
# 260184                                  True  ...                      False
#
#         Site EUI (kBtu/sq ft)  Source EUI (kBtu/sq ft)  \
# ID
# 252064                   True                     True
# 232458                   True                     True
# 254616                   True                     True
# 103812                   True                     True
# 254073                   True                     True
# ...                       ...                      ...
# 260132                   True                     True
# 260135                   True                    False
# 260149                   True                     True
# 260150                   True                     True
# 260184                   True                    False
#
#         Weather Normalized Site EUI (kBtu/sq ft)  \
# ID
# 252064                                      True
# 232458                                      True
# 254616                                      True
# 103812                                      True
# 254073                                      True
# ...                                          ...
# 260132                                      True
# 260135                                     False
# 260149                                      True
# 260150                                      True
# 260184                                     False
#
#         Weather Normalized Source EUI (kBtu/sq ft)  \
# ID
# 252064                                        True
# 232458                                        True
# 254616                                        True
# 103812                                        True
# 254073                                        True
# ...                                            ...
# 260132                                       False
# 260135                                       False
# 260149                                       False
# 260150                                       False
# 260184                                       False
#
#         Total GHG Emissions (Metric Tons CO2e)  GHG Intensity (kg CO2e/sq ft)  \
# ID
# 252064                                    True                           True
# 232458                                    True                           True
# 254616                                    True                           True
# 103812                                    True                           True
# 254073                                    True                           True
# ...                                        ...                            ...
# 260132                                   False                          False
# 260135                                   False                          False
# 260149                                    True                           True
# 260150                                    True                           True
# 260184                                   False                          False
#
#         Latitude  Longitude  Location
# ID
# 252064      True       True      True
# 232458      True       True      True
# 254616      True       True      True
# 103812      True       True      True
# 254073      True       True      True
# ...          ...        ...       ...
# 260132      True       True      True
# 260135      True       True      True
# 260149      True       True      True
# 260150      True       True      True
# 260184      True       True      True
#
# [17254 rows x 28 columns]>

# %%
#Change Column Names
